# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
eurusd_D15 = pd.read_csv('./data/EURUSD15.csv')

# %%
df = []
for i in eurusd_D15.values:
    df.append(str(i).replace("['", "").replace("']", "").split("\\t"))
    
data = pd.DataFrame(df, columns=['Date', 'Open', 'High', 'Low', 'Close', 'Volume'])

# %%
data = data.set_index('time')
for i in data:
    data[i] = data[i].astype(float)

# %%
scaler = StandardScaler()
for c in data.columns:
    data[c+'_Norm'] = scaler.fit_transform(data[c].to_numpy().reshape(-1, 1))
data = data.dropna()

# %%
data
# Out:
#                      open      max      min    close     vol  open_Norm  \
# time
# 2019-04-05 15:45  1.12174  1.12191  1.12165  1.12169  4331.0  -0.418877
# 2019-04-05 16:00  1.12169  1.12198  1.12153  1.12188  4699.0  -0.420046
# 2019-04-05 16:15  1.12188  1.12197  1.12131  1.12136  4139.0  -0.415603
# 2019-04-05 16:30  1.12137  1.12180  1.12130  1.12173  4125.0  -0.427529
# 2019-04-05 16:45  1.12172  1.12192  1.12146  1.12146  3542.0  -0.419345
# ...                   ...      ...      ...      ...     ...        ...
# 2021-04-08 17:45  1.19217  1.19217  1.19179  1.19179   731.0   1.228051
# 2021-04-08 18:00  1.19180  1.19183  1.19161  1.19167  1256.0   1.219399
# 2021-04-08 18:15  1.19166  1.19171  1.19132  1.19152  1034.0   1.216125
# 2021-04-08 18:30  1.19153  1.19175  1.19149  1.19150   879.0   1.213085
# 2021-04-08 18:45  1.19151  1.19173  1.19136  1.19169   712.0   1.212618
#
#                   max_Norm  min_Norm  close_Norm  vol_Norm
# time
# 2019-04-05 15:45 -0.422194 -0.413607   -0.420050  0.127045
# 2019-04-05 16:00 -0.420558 -0.416415   -0.415607  0.171985
# 2019-04-05 16:15 -0.420792 -0.421561   -0.427767  0.103598
# 2019-04-05 16:30 -0.424766 -0.421795   -0.419115  0.101888
# 2019-04-05 16:45 -0.421961 -0.418052   -0.425428  0.030692
# ...                    ...       ...         ...       ...
# 2021-04-08 17:45  1.220183  1.227164    1.219138 -0.312590
# 2021-04-08 18:00  1.212236  1.222953    1.216332 -0.248476
# 2021-04-08 18:15  1.209431  1.216169    1.212824 -0.275587
# 2021-04-08 18:30  1.210366  1.220146    1.212357 -0.294516
# 2021-04-08 18:45  1.209898  1.217105    1.216800 -0.314910
#
# [49999 rows x 10 columns]

# %%
train = data[pd.to_datetime('01-01-2010'):pd.to_datetime('01-01-2015')]
train_x = data[['Open_Norm','High_Norm','Low_Norm','Close_Norm','Volume_Norm']].to_numpy()
train_y = data[['Return_Norm']].to_numpy()
val = data[pd.to_datetime('01-01-2015'):pd.to_datetime('01-01-2017')]
val_x = val[['Open_Norm','High_Norm','Low_Norm','Close_Norm','Volume_Norm']].to_numpy()
val_y = val[['Return_Norm']].to_numpy()
test = data[pd.to_datetime('01-01-2017'):pd.to_datetime('01-01-2020')]
test_x = test[['Open_Norm','High_Norm','Low_Norm','Close_Norm','Volume_Norm']]
test_y = test[['Return_Norm', 'Return']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: Timestamp('2010-01-01 00:00:00')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3/dist-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    5163         try:
# -> 5164             slc = self.get_loc(label)
#    5165         except KeyError as err:
#
# /usr/lib/python3/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: Timestamp('2010-01-01 00:00:00')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-81f6b73def6a> in <module>
# ----> 1 train = data[pd.to_datetime('01-01-2010'):pd.to_datetime('01-01-2015')]
#       2 train_x = data[['Open_Norm','High_Norm','Low_Norm','Close_Norm','Volume_Norm']].to_numpy()
#       3 train_y = data[['Return_Norm']].to_numpy()
#       4 val = data[pd.to_datetime('01-01-2015'):pd.to_datetime('01-01-2017')]
#       5 val_x = val[['Open_Norm','High_Norm','Low_Norm','Close_Norm','Volume_Norm']].to_numpy()
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2974
#    2975         # Do we have a slicer (on rows)?
# -> 2976         indexer = convert_to_index_sliceable(self, key)
#    2977         if indexer is not None:
#    2978             return self._slice(indexer, axis=0)
#
# /usr/lib/python3/dist-packages/pandas/core/indexing.py in convert_to_index_sliceable(obj, key)
#    2356     idx = obj.index
#    2357     if isinstance(key, slice):
# -> 2358         return idx._convert_slice_indexer(key, kind="getitem")
#    2359
#    2360     elif isinstance(key, str):
#
# /usr/lib/python3/dist-packages/pandas/core/indexes/base.py in _convert_slice_indexer(self, key, kind)
#    3214         else:
#    3215             try:
# -> 3216                 indexer = self.slice_indexer(start, stop, step, kind=kind)
#    3217             except Exception:
#    3218                 if is_index_slice:
#
# /usr/lib/python3/dist-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    5032         slice(1, 3)
#    5033         """
# -> 5034         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    5035
#    5036         # return a slice
#
# /usr/lib/python3/dist-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    5246         start_slice = None
#    5247         if start is not None:
# -> 5248             start_slice = self.get_slice_bound(start, "left", kind)
#    5249         if start_slice is None:
#    5250             start_slice = 0
#
# /usr/lib/python3/dist-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    5165         except KeyError as err:
#    5166             try:
# -> 5167                 return self._searchsorted_monotonic(label, side)
#    5168             except ValueError:
#    5169                 # raise the original KeyError
#
# /usr/lib/python3/dist-packages/pandas/core/indexes/base.py in _searchsorted_monotonic(self, label, side)
#    5116     def _searchsorted_monotonic(self, label, side="left"):
#    5117         if self.is_monotonic_increasing:
# -> 5118             return self.searchsorted(label, side=side)
#    5119         elif self.is_monotonic_decreasing:
#    5120             # np.searchsorted expects ascending sort order, have to reverse
#
# /usr/lib/python3/dist-packages/pandas/core/base.py in searchsorted(self, value, side, sorter)
#    1616     @Appender(_shared_docs["searchsorted"])
#    1617     def searchsorted(self, value, side="left", sorter=None):
# -> 1618         return algorithms.searchsorted(self._values, value, side=side, sorter=sorter)
#    1619
#    1620     def drop_duplicates(self, keep="first", inplace=False):
#
# /usr/lib/python3/dist-packages/pandas/core/algorithms.py in searchsorted(arr, value, side, sorter)
#    1885         value = value_ser[0] if is_scalar(value) else value_ser
#    1886
# -> 1887     result = arr.searchsorted(value, side=side, sorter=sorter)
#    1888     return result
#    1889
#
# TypeError: '<' not supported between instances of 'str' and 'Timestamp'
